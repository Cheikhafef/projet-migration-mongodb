# %% [markdown]
# ## 🌐 Téléchargement des données InfoClimat (JSON)
# Ce script télécharge un fichier JSON hébergé sur un bucket S3, puis l’enregistre localement dans un format propre et lisible. Il constitue la première étape d’ingestion des données météorologiques dans le pipeline.
#
# ## 🔧 Fonctionnement
# Envoie une requête HTTP GET vers l’URL S3
#
# Charge la réponse JSON en mémoire
#
# Sauvegarde les données dans un fichier local InfoClimat.json
#
# Formate le JSON avec indentation pour faciliter la lecture

# %%
import requests
import json

url = "https://s3.eu-west-1.amazonaws.com/course.oc-static.com/projects/922_Data+Engineer/922_P8/Data_Source1_011024-071024.json"

response = requests.get(url)
data = response.json()

with open("InfoClimat.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

print("Téléchargement terminé → InfoClimat.json")
# Out:
# Téléchargement terminé → InfoClimat.json
